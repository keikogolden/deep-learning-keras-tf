# %%
import pandas as pd

# %%
df1 = pd.read_excel("C:/Users/KeikoGolden/ComputationalLiguistics/KE397_1500skillsCandidate/SnapshotAugust8/anay.xlsx")
df2 = pd.read_excel("C:/Users/KeikoGolden/ComputationalLiguistics/KE397_1500skillsCandidate/SnapshotAugust8/cassady.xlsx")
df3 = pd.read_excel("C:/Users/KeikoGolden/ComputationalLiguistics/KE397_1500skillsCandidate/SnapshotAugust8/desiree.xlsx")
df4 = pd.read_excel("C:/Users/KeikoGolden/ComputationalLiguistics/KE397_1500skillsCandidate/SnapshotAugust8/ethan.xlsx")
df5 = pd.read_excel("C:/Users/KeikoGolden/ComputationalLiguistics/KE397_1500skillsCandidate/SnapshotAugust8/syed.xlsx")

# %%
all_df = pd.concat([df1, df2, df3, df4, df5])

# %%
len(all_df)
# Out:
# 28217

# %%
all_df.head(5)
# Out:
#    Unnamed: 0                          skill_title  Suggested_skill_title  \
# 0     17962.0                Intersystems Ensemble  InterSystems Ensemble
# 1     17963.0                            Intertest              InterTest
# 2     17964.0  Intervention and Discharge Planning                    NaN
# 3     17965.0                Intervention Planning                    NaN
# 4     17966.0                  Intervention Skills                    NaN
#
#   skill_or_not in_ontology                                          def_short  \
# 0          YES         NaN  This is a skill related to using the software ...
# 1           NO         NaN  This is a skill related to using the software ...
# 2          YES         NaN  This is a skill related to planning and implem...
# 3          YES         NaN  This is a skill related to planning and implem...
# 4          YES         NaN  This is a skill related to having skills in im...
#
#   def_accurate_or_not another_interpretation def_formatting_ok_or_not  \
# 0                 YES                    NaN                      YES
# 1                 NaN                    NaN                      NaN
# 2                 YES                    NaN                      YES
# 3                 YES                    NaN                      YES
# 4                 YES                    NaN                      YES
#
#   corrected_def         Notes  duplicate_or_bigram  977  0.16318690496074828  \
# 0           NaN           NaN                  NaN  NaN                  NaN
# 1           NaN  Company Name                  NaN  NaN                  NaN
# 2           NaN           NaN                  NaN  NaN                  NaN
# 3           NaN           NaN                  NaN  NaN                  NaN
# 4           NaN           NaN                  NaN  NaN                  NaN
#
#    651  Unnamed: 11  Unnamed: 12  Unnamed: 13  Corrected_Format
# 0  NaN          NaN          NaN          NaN               NaN
# 1  NaN          NaN          NaN          NaN               NaN
# 2  NaN          NaN          NaN          NaN               NaN
# 3  NaN          NaN          NaN          NaN               NaN
# 4  NaN          NaN          NaN          NaN               NaN

# %%
# If you use the lemmas to count morphemes, enable the "lemmas.append(token.lemma_)" and disable the "print(skill + ": " + "NOUN" + "   Lemma: " + token.lemma_)""
import spacy

nlp = spacy.load("en_core_web_lg")

lemmas = []
for skill in all_df.skill_title.tolist():
    doc = nlp(skill)
    if len(doc)== 1:                               #Find unigram
        for token in doc:                          
            if token.pos_ == "NOUN":               #Find noun
                print(skill + ": " + "NOUN" + "   Lemma: " + token.lemma_)
                lemma = token.lemma_
                lemmas.append(lemma)
# Out:
# Apatar: NOUN   Lemma: apatar
# trackhoe: NOUN   Lemma: trackhoe
# trader: NOUN   Lemma: trader
# Trados: NOUN   Lemma: trado
# Nrp: NOUN   Lemma: nrp
# Ladles: NOUN   Lemma: ladle
# Ormb: NOUN   Lemma: ormb
# Os/400: NOUN   Lemma: os/400
# Osb: NOUN   Lemma: osb
# Ospfv3: NOUN   Lemma: ospfv3
# Ou: NOUN   Lemma: ou
# Ouac: NOUN   Lemma: ouac
# Preceptor: NOUN   Lemma: preceptor
# Preceptorship: NOUN   Lemma: preceptorship
# Precertifications: NOUN   Lemma: precertification
# Medisked: NOUN   Lemma: medisked
# BenAssist: NOUN   Lemma: benassist
# Groundkeeper: NOUN   Lemma: groundkeeper
# Groundsmen: NOUN   Lemma: groundsmen
# Stabilometers: NOUN   Lemma: stabilometer
# Homemaking: NOUN   Lemma: homemaking
# Homeschooling: NOUN   Lemma: homeschooling
# Pgadmin: NOUN   Lemma: pgadmin
# philanthropist: NOUN   Lemma: philanthropist
# Timefinder: NOUN   Lemma: timefinder
# Timeslips: NOUN   Lemma: timeslip
# Tinter: NOUN   Lemma: tinter
# Tinyterm: NOUN   Lemma: tinyterm
# Tires: NOUN   Lemma: tire
# Title: NOUN   Lemma: title
# Titration: NOUN   Lemma: titration
# Spelling: NOUN   Lemma: spelling
# pitmaster: NOUN   Lemma: pitmaster
# pitstop: NOUN   Lemma: pitstop
# Pixis: NOUN   Lemma: pixis
# pizzaiolo: NOUN   Lemma: pizzaiolo
# Planers: NOUN   Lemma: planer
# Planit: NOUN   Lemma: planit
# Plant3D: NOUN   Lemma: plant3d
# Plantspace: NOUN   Lemma: plantspace
# Planview: NOUN   Lemma: planview
# Kickboards: NOUN   Lemma: kickboard
# Uroflowmeters: NOUN   Lemma: uroflowmeter
# Stimplan: NOUN   Lemma: stimplan
# Stockpicker: NOUN   Lemma: stockpicker
# Volumeters: NOUN   Lemma: volumeter
# Chokers: NOUN   Lemma: choker
# tar: NOUN   Lemma: tar
# tarps: NOUN   Lemma: tarp
# tarts: NOUN   Lemma: tart
# Screenprint: NOUN   Lemma: screenprint
# Screenwriting: NOUN   Lemma: screenwriting
# Scrubs: NOUN   Lemma: scrub
# SDS/2: NOUN   Lemma: sds/2
# Sealants: NOUN   Lemma: sealant
# Seals: NOUN   Lemma: seal
# InsideSales.com: NOUN   Lemma: InsideSales.com
# Powerchurch: NOUN   Lemma: powerchurch
# Powerepoint: NOUN   Lemma: powerepoint
# Powerjack: NOUN   Lemma: powerjack
# Powerpint: NOUN   Lemma: powerpint
# Powerplant: NOUN   Lemma: powerplant
# Powerplay: NOUN   Lemma: powerplay
# Powerpont: NOUN   Lemma: powerpont
# Powerscribe: NOUN   Lemma: powerscribe
# Powerscribe: NOUN   Lemma: powerscribe
# Equities: NOUN   Lemma: equity
# Erecruit: NOUN   Lemma: erecruit
# Eroes: NOUN   Lemma: eroe
# Ers: NOUN   Lemma: ers
# Marksmanship: NOUN   Lemma: marksmanship
# Opticks: NOUN   Lemma: optick
# Quickboks: NOUN   Lemma: quickbok
# Quickcare: NOUN   Lemma: quickcare
# Quicklaw: NOUN   Lemma: quicklaw
# Quicktax: NOUN   Lemma: quicktax
# Quikbooks: NOUN   Lemma: quikbook
# Quip: NOUN   Lemma: quip
# Quizlet: NOUN   Lemma: quizlet
# Quotations: NOUN   Lemma: quotation
# Mangodb: NOUN   Lemma: mangodb
# Manlift: NOUN   Lemma: manlift
# Manpower: NOUN   Lemma: manpower
# Mantis: NOUN   Lemma: mantis
# Mantisbt: NOUN   Lemma: mantisbt
# Epitome: NOUN   Lemma: epitome
# Epoc: NOUN   Lemma: epoc
# Spacewalk: NOUN   Lemma: spacewalk
# Distillers: NOUN   Lemma: distiller
# Ditchers: NOUN   Lemma: ditcher
# scouting: NOUN   Lemma: scouting
# FireWire: NOUN   Lemma: firewire
# singleton: NOUN   Lemma: singleton
# Ahera: NOUN   Lemma: ahera
# Aiag: NOUN   Lemma: Aiag
# Aide: NOUN   Lemma: aide
# Aidet: NOUN   Lemma: aidet
# Subsoilers: NOUN   Lemma: subsoiler
# Modelmaking: NOUN   Lemma: modelmaking
# Multifonds: NOUN   Lemma: multifond
# Tedds: NOUN   Lemma: tedd
# Tees: NOUN   Lemma: tee
# Tegile: NOUN   Lemma: tegile
# Teller: NOUN   Lemma: teller
# Temp: NOUN   Lemma: temp
# SalesInSync: NOUN   Lemma: salesinsync
# Investigo: NOUN   Lemma: investigo
# EZAnalyze: NOUN   Lemma: EZAnalyze
# Earpieces: NOUN   Lemma: earpiece
# EarthVision: NOUN   Lemma: earthvision
# Echometers: NOUN   Lemma: echometer
# Gmail: NOUN   Lemma: gmail
# Saflok: NOUN   Lemma: saflok
# Saftey: NOUN   Lemma: saftey
# Sai: NOUN   Lemma: sai
# Salad: NOUN   Lemma: salad
# Saleman: NOUN   Lemma: saleman
# Perceptiveness: NOUN   Lemma: perceptiveness
# Marlinspikes: NOUN   Lemma: marlinspike
# Masks: NOUN   Lemma: mask
# SUMIFS: NOUN   Lemma: sumif
# Strainers: NOUN   Lemma: strainer
# Strawlines: NOUN   Lemma: strawline
# Strollers: NOUN   Lemma: stroller
# phpBB: NOUN   Lemma: phpbb
# Stockpots: NOUN   Lemma: stockpot
# Flammap: NOUN   Lemma: flammap
# Unityscript: NOUN   Lemma: unityscript
# patron: NOUN   Lemma: patron
# Pay@Work: NOUN   Lemma: pay@work
# Payables: NOUN   Lemma: payable
# payloader: NOUN   Lemma: payloader
# Payloaders: NOUN   Lemma: payloader
# Saddles: NOUN   Lemma: saddle
# Torvanes: NOUN   Lemma: torvane
# Loadcells: NOUN   Lemma: loadcell
# moodboard: NOUN   Lemma: moodboard
# Moodboards: NOUN   Lemma: moodboard
# Moqups: NOUN   Lemma: moqup
# SQLPlus: NOUN   Lemma: sqlplus
# ETOM: NOUN   Lemma: etom
# Etouches: NOUN   Lemma: etouche
# Etq: NOUN   Lemma: etq
# evaluator: NOUN   Lemma: evaluator
# Loupes: NOUN   Lemma: loupe
# Respirator: NOUN   Lemma: respirator
# Arterial: NOUN   Lemma: arterial
# Fumigators: NOUN   Lemma: fumigator
# Prophix: NOUN   Lemma: prophix
# Prophy: NOUN   Lemma: prophy
# Oscillographs: NOUN   Lemma: oscillograph
# Aecosim: NOUN   Lemma: aecosim
# Aethna: NOUN   Lemma: Aethna
# skiploader: NOUN   Lemma: skiploader
# Skydiving: NOUN   Lemma: skydiving
# Consolidometers: NOUN   Lemma: consolidometer
# Impingers: NOUN   Lemma: impinger
# Porosimeters: NOUN   Lemma: porosimeter
# Recrystallization: NOUN   Lemma: recrystallization
# punchlist: NOUN   Lemma: punchlist
# Accpac: NOUN   Lemma: Accpac
# Accpac: NOUN   Lemma: Accpac
# Skyscape: NOUN   Lemma: skyscape
# Tuggers: NOUN   Lemma: tugger
# Turbidimeters: NOUN   Lemma: turbidimeter
# Pipenet: NOUN   Lemma: pipenet
# Hiab: NOUN   Lemma: hiab
# AIRMaster: NOUN   Lemma: airmaster
# dessicators: NOUN   Lemma: dessicator
# Gretl: NOUN   Lemma: gretl
# Grills: NOUN   Lemma: grill
# Grlweap: NOUN   Lemma: grlweap
# ClickSoftware: NOUN   Lemma: clicksoftware
# victimization: NOUN   Lemma: victimization
# Winterization: NOUN   Lemma: winterization
# Accompaniment: NOUN   Lemma: accompaniment
# Accessibility: NOUN   Lemma: accessibility
# TouchDesigner: NOUN   Lemma: touchdesigner
# magnetometers: NOUN   Lemma: magnetometer
# whistleblower: NOUN   Lemma: whistleblower
# Accreditation: NOUN   Lemma: accreditation
# Receiverships: NOUN   Lemma: receivership
# receptionists: NOUN   Lemma: receptionist
# reexamination: NOUN   Lemma: reexamination
# Reinforcement: NOUN   Lemma: reinforcement
# Papervision3D: NOUN   Lemma: papervision3d
# Orchestration: NOUN   Lemma: orchestration
# Privatization: NOUN   Lemma: privatization
# Profitability: NOUN   Lemma: profitability
# projectionist: NOUN   Lemma: projectionist
# Pronunciation: NOUN   Lemma: pronunciation
# phpDocumentor: NOUN   Lemma: phpdocumentor
# Preceptorship: NOUN   Lemma: preceptorship
# Randomization: NOUN   Lemma: randomization
# questionnaire: NOUN   Lemma: questionnaire
# Petrochemical: NOUN   Lemma: petrochemical
# Quartermaster: NOUN   Lemma: quartermaster
# Burrellesluce: NOUN   Lemma: burrellesluce
# Modernization: NOUN   Lemma: modernization
# specification: NOUN   Lemma: specification
# Sportsmanship: NOUN   Lemma: sportsmanship
# Synchronicity: NOUN   Lemma: synchronicity
# Microbalances: NOUN   Lemma: microbalance
# Methodologies: NOUN   Lemma: methodology
# anonymization: NOUN   Lemma: anonymization
# anniversaries: NOUN   Lemma: anniversary
# Metacognition: NOUN   Lemma: metacognition
# Straightedges: NOUN   Lemma: straightedge
# Supercollider: NOUN   Lemma: supercollider
# suppositories: NOUN   Lemma: suppository
# Survivability: NOUN   Lemma: survivability
# autobiography: NOUN   Lemma: autobiography
# serialization: NOUN   Lemma: serialization
# socialization: NOUN   Lemma: socialization
# Certification: NOUN   Lemma: certification
# Authorization: NOUN   Lemma: authorization
# RetrievalWare: NOUN   Lemma: retrievalware
# Interrogation: NOUN   Lemma: interrogation
# documentaries: NOUN   Lemma: documentary
# Consciousness: NOUN   Lemma: consciousness
# connectedness: NOUN   Lemma: connectedness
# Confectionery: NOUN   Lemma: confectionery
# Crowdsourcing: NOUN   Lemma: crowdsourcing
# dissertations: NOUN   Lemma: dissertation
# Homeschooling: NOUN   Lemma: homeschooling
# Intuitiveness: NOUN   Lemma: intuitiveness
# Expropriation: NOUN   Lemma: expropriation
# explosimeters: NOUN   Lemma: explosimeter
# galvanometers: NOUN   Lemma: galvanometer
# Grantsmanship: NOUN   Lemma: grantsmanship
# Glycosylation: NOUN   Lemma: glycosylation
# interactivity: NOUN   Lemma: interactivity
# globalisation: NOUN   Lemma: globalisation
# Globalization: NOUN   Lemma: globalization
# Intermediates: NOUN   Lemma: intermediate
# Constructware: NOUN   Lemma: constructware
# Guardianships: NOUN   Lemma: guardianship
# Growthmindset: NOUN   Lemma: growthmindset
# embellishment: NOUN   Lemma: embellishment
# densitometers: NOUN   Lemma: densitometer
# JasperReports: NOUN   Lemma: jasperreport
# Employability: NOUN   Lemma: employability
# dependability: NOUN   Lemma: dependability
# disbursements: NOUN   Lemma: disbursement
# Enlightenment: NOUN   Lemma: enlightenment
# Eco_Upgrade22: NOUN   Lemma: Eco_Upgrade22
# Entertainment: NOUN   Lemma: entertainment
# Effectiveness: NOUN   Lemma: effectiveness
# Iphoneography: NOUN   Lemma: iphoneography
# Electrocution: NOUN   Lemma: electrocution
# Incorporation: NOUN   Lemma: incorporation
# modularization: NOUN   Lemma: modularization
# philanthropist: NOUN   Lemma: philanthropist
# Petrochemicals: NOUN   Lemma: petrochemical
# photocatalysis: NOUN   Lemma: photocatalysis
# Potentiometers: NOUN   Lemma: potentiometer
# Postproduction: NOUN   Lemma: postproduction
# Implementation: NOUN   Lemma: implementation
# Impersonations: NOUN   Lemma: impersonation
# Naturalization: NOUN   Lemma: naturalization
# Hyperlipidemia: NOUN   Lemma: hyperlipidemia
# Historiography: NOUN   Lemma: historiography
# OpenSceneGraph: NOUN   Lemma: openscenegraph
# openFrameworks: NOUN   Lemma: openframework
# Categorization: NOUN   Lemma: categorization
# discriminators: NOUN   Lemma: discriminator
# ActiveCampaign: NOUN   Lemma: activecampaign
# Humidification: NOUN   Lemma: humidification
# Discrimination: NOUN   Lemma: discrimination
# Multiplication: NOUN   Lemma: multiplication
# municipalities: NOUN   Lemma: municipality
# disambiguation: NOUN   Lemma: disambiguation
# Weatherization: NOUN   Lemma: weatherization
# transportation: NOUN   Lemma: transportation
# Transformation: NOUN   Lemma: transformation
# specifications: NOUN   Lemma: specification
# Authentication: NOUN   Lemma: authentication
# autocollimator: NOUN   Lemma: autocollimator
# Cybersquatting: NOUN   Lemma: cybersquatting
# Antiharassment: NOUN   Lemma: antiharassment
# Sustainability: NOUN   Lemma: sustainability
# supercomputers: NOUN   Lemma: supercomputer
# supercapacitor: NOUN   Lemma: supercapacitor
# superannuation: NOUN   Lemma: superannuation
# Apprenticeship: NOUN   Lemma: apprenticeship
# Bioconjugation: NOUN   Lemma: bioconjugation
# Bioequivalence: NOUN   Lemma: bioequivalence
# Reorganisation: NOUN   Lemma: reorganisation
# revitalization: NOUN   Lemma: revitalization
# Undeliverables: NOUN   Lemma: undeliverable
# Correspondance: NOUN   Lemma: correspondance
# Responsiveness: NOUN   Lemma: responsiveness
# Decelerometers: NOUN   Lemma: decelerometer
# Aeroelasticity: NOUN   Lemma: aeroelasticity
# Reconstruction: NOUN   Lemma: reconstruction
# semiconductors: NOUN   Lemma: semiconductor
# Securitization: NOUN   Lemma: securitization
# Securitisation: NOUN   Lemma: securitisation
# accelerometers: NOUN   Lemma: accelerometer
# Investissement: NOUN   Lemma: investissement
# Infrastructure: NOUN   Lemma: infrastructure
# Classification: NOUN   Lemma: classification
# Confidentiality: NOUN   Lemma: confidentiality
# Democratization: NOUN   Lemma: democratization
# Crashworthiness: NOUN   Lemma: crashworthiness
# Standardization: NOUN   Lemma: standardization
# interconnection: NOUN   Lemma: interconnection
# autocollimators: NOUN   Lemma: autocollimator
# Defiscalisation: NOUN   Lemma: defiscalisation
# interrogatories: NOUN   Lemma: interrogatory
# maintainability: NOUN   Lemma: maintainability
# Personalization: NOUN   Lemma: personalization
# Electrification: NOUN   Lemma: electrification
# Anticoagulation: NOUN   Lemma: anticoagulation
# Internalization: NOUN   Lemma: internalization
# Supercapacitors: NOUN   Lemma: supercapacitor
# Approachability: NOUN   Lemma: approachability
# Interoperability: NOUN   Lemma: interoperability
# PerformancePoint: NOUN   Lemma: performancepoint
# Electropolishing: NOUN   Lemma: electropolishing
# Constructability: NOUN   Lemma: constructability
# preauthorization: NOUN   Lemma: preauthorization
# Previsualization: NOUN   Lemma: previsualization
# electromechanics: NOUN   Lemma: electromechanic
# Nonproliferation: NOUN   Lemma: nonproliferation
# Hyperconvergence: NOUN   Lemma: hyperconvergence
# interdisciplinary: NOUN   Lemma: interdisciplinary
# Recrystallization: NOUN   Lemma: recrystallization
# Counterinsurgency: NOUN   Lemma: counterinsurgency
# conceptualization: NOUN   Lemma: conceptualization
# Hyperpigmentation: NOUN   Lemma: hyperpigmentation
# Approvisionnement: NOUN   Lemma: approvisionnement
# Chemostratigraphy: NOUN   Lemma: chemostratigraphy
# Industrialisation: NOUN   Lemma: industrialisation
# Depersonalization: NOUN   Lemma: depersonalization
# industrialization: NOUN   Lemma: industrialization
# Employeerelations: NOUN   Lemma: employeerelation
# Intersectionality: NOUN   Lemma: intersectionality
# Counterintelligence: NOUN   Lemma: counterintelligence
# Interdisciplinarity: NOUN   Lemma: interdisciplinarity
# internationalization: NOUN   Lemma: internationalization
# Analyzation: NOUN   Lemma: analyzation
# Analyzer: NOUN   Lemma: analyzer
# Velocimeters: NOUN   Lemma: velocimeter
# Velometers: NOUN   Lemma: velometer
# Inserts: NOUN   Lemma: insert
# Insomnia: NOUN   Lemma: insomnia
# amputee: NOUN   Lemma: amputee
# AMSI: NOUN   Lemma: amsi
# Staffworks: NOUN   Lemma: staffwork
# Stairways: NOUN   Lemma: stairway
# Stamis: NOUN   Lemma: stamis
# Coeus: NOUN   Lemma: coeus
# Elawsoftware: NOUN   Lemma: elawsoftware
# Epsych: NOUN   Lemma: Epsych
# Etritionware: NOUN   Lemma: etritionware
# Planers: NOUN   Lemma: planer
# Platemakers: NOUN   Lemma: platemaker
# Rasps: NOUN   Lemma: rasp
# RazorSync: NOUN   Lemma: razorsync
# plasterer: NOUN   Lemma: plasterer
# polysaccharide: NOUN   Lemma: polysaccharide
# porter: NOUN   Lemma: porter
# Portico: NOUN   Lemma: portico
# TherAssist: NOUN   Lemma: therassist
# accidents: NOUN   Lemma: accident
# accompanist: NOUN   Lemma: accompanist
# Pullers: NOUN   Lemma: puller
# Fliers: NOUN   Lemma: flier
# Floorplans: NOUN   Lemma: floorplan
# Floorset: NOUN   Lemma: floorset
# NISPOM: NOUN   Lemma: nispom
# Cauterizers: NOUN   Lemma: cauterizer
# Cavitrons: NOUN   Lemma: cavitron
# Availity: NOUN   Lemma: availity
# Avamark: NOUN   Lemma: avamark
# Aveksa: NOUN   Lemma: aveksa
# Videophones: NOUN   Lemma: videophone
# Vine: NOUN   Lemma: vine
# titrators: NOUN   Lemma: titrator
# TokenX: NOUN   Lemma: tokenx
# tongs: NOUN   Lemma: tong
# Dryers: NOUN   Lemma: dryer
# Theromcouples: NOUN   Lemma: theromcouple
# Chem2Pac: NOUN   Lemma: chem2pac
# Pastel: NOUN   Lemma: pastel
# Pathnet: NOUN   Lemma: pathnet
# Msaccess: NOUN   Lemma: msaccess
# Msexcel: NOUN   Lemma: msexcel
# Msoutlook: NOUN   Lemma: msoutlook
# Appsync: NOUN   Lemma: appsync
# Apptus: NOUN   Lemma: apptus
# Appx: NOUN   Lemma: appx
# Apraxia: NOUN   Lemma: apraxia
# Aptitude: NOUN   Lemma: aptitude
# Apto: NOUN   Lemma: apto
# Aql: NOUN   Lemma: aql
# Aqmd: NOUN   Lemma: aqmd
# Aquisitions: NOUN   Lemma: aquisition
# Ar: NOUN   Lemma: ar
# Arbitrator: NOUN   Lemma: arbitrator
# Arcona: NOUN   Lemma: arcona
# Arcs: NOUN   Lemma: arc
# Arcserv: NOUN   Lemma: arcserv
# Toastmasters: NOUN   Lemma: toastmaster
# Solve360: NOUN   Lemma: Solve360
# solver: NOUN   Lemma: solver
# SavingFace: NOUN   Lemma: savingface
# Sawbucks: NOUN   Lemma: sawbuck
# Netfinity: NOUN   Lemma: netfinity
# Netforum: NOUN   Lemma: netforum
# Netronline: NOUN   Lemma: netronline
# Neuralog: NOUN   Lemma: neuralog
# Locksmithing: NOUN   Lemma: locksmithing
# Lodging: NOUN   Lemma: lodging
# Vaccum: NOUN   Lemma: vaccum
# Vaccuming: NOUN   Lemma: vaccuming
# Gillnetters: NOUN   Lemma: gillnetter
# Etouches: NOUN   Lemma: etouche
# IChartPlus: NOUN   Lemma: ichartplus
# IEmployee: NOUN   Lemma: IEmployee
# IShip: NOUN   Lemma: iship
# PolicyIQ: NOUN   Lemma: policyiq
# SEOClarity: NOUN   Lemma: seoclarity
# Potentiometry: NOUN   Lemma: potentiometry
# Powdercoat: NOUN   Lemma: powdercoat
# Interdev: NOUN   Lemma: interdev
# Grapplers: NOUN   Lemma: grappler
# Graspers: NOUN   Lemma: grasper
# Gravers: NOUN   Lemma: graver
# Gravimeters: NOUN   Lemma: gravimeter
# Handcuffs: NOUN   Lemma: handcuff
# Electroporators: NOUN   Lemma: electroporator
# Canes: NOUN   Lemma: cane
# ArtPro: NOUN   Lemma: artpro
# Bridgeplates: NOUN   Lemma: bridgeplate
# BrioQuery: NOUN   Lemma: brioquery
# Titrators: NOUN   Lemma: titrator
# Tkprof: NOUN   Lemma: tkprof
# Hoedads: NOUN   Lemma: hoedad
# Eyelashes: NOUN   Lemma: eyelash
# PHYLIP: NOUN   Lemma: phylip
# PIBWin: NOUN   Lemma: pibwin
# PWscf: NOUN   Lemma: pwscf
# Tuggers: NOUN   Lemma: tugger
# Tuina: NOUN   Lemma: tuina
# SF6: NOUN   Lemma: sf6
# Essays: NOUN   Lemma: essay
# Buffet: NOUN   Lemma: buffet
# Pastry: NOUN   Lemma: pastry
# retort: NOUN   Lemma: retort
# DO-160: NOUN   Lemma: do-160
# emblem: NOUN   Lemma: emblem
# Rhythm: NOUN   Lemma: rhythm
# empire: NOUN   Lemma: empire
# djbdns: NOUN   Lemma: djbdns
# Pastas: NOUN   Lemma: pasta
# Rights: NOUN   Lemma: right
# enemas: NOUN   Lemma: enema
# DFSORT: NOUN   Lemma: dfsort
# Piracy: NOUN   Lemma: piracy
# design: NOUN   Lemma: design
# beacon: NOUN   Lemma: beacon
# diadem: NOUN   Lemma: diadem
# people: NOUN   Lemma: people
# DIBELS: NOUN   Lemma: dibel
# Digium: NOUN   Lemma: digium
# bazaar: NOUN   Lemma: bazaar
# bedpan: NOUN   Lemma: bedpan
# RPG400: NOUN   Lemma: RPG400
# Disney: NOUN   Lemma: disney
# pillar: NOUN   Lemma: pillar
# busbar: NOUN   Lemma: busbar
# rocket: NOUN   Lemma: rocket
# blinds: NOUN   Lemma: blind
# Blazor: NOUN   Lemma: blazor
# dragon: NOUN   Lemma: dragon
# Booker: NOUN   Lemma: booker
# Rakugo: NOUN   Lemma: rakugo
# Blades: NOUN   Lemma: blade
# Prompt: NOUN   Lemma: prompt
# Booths: NOUN   Lemma: booth
# Rapids: NOUN   Lemma: rapid
# ratios: NOUN   Lemma: ratio
# dotCMS: NOUN   Lemma: dotcms
# dreams: NOUN   Lemma: dream
# drinks: NOUN   Lemma: drink
# duties: NOUN   Lemma: duty
# Blurbs: NOUN   Lemma: blurb
# Pumper: NOUN   Lemma: pumper
# Puller: NOUN   Lemma: puller
# Drools: NOUN   Lemma: drool
# Rabbit: NOUN   Lemma: rabbit
# Parole: NOUN   Lemma: parole
# Radius: NOUN   Lemma: radius
# Relays: NOUN   Lemma: relay
# bridge: NOUN   Lemma: bridge
# Relief: NOUN   Lemma: relief
# Biases: NOUN   Lemma: bias
# porter: NOUN   Lemma: porter
# eFront: NOUN   Lemma: eFront
# Policy: NOUN   Lemma: policy
# EFTPOS: NOUN   Lemma: eftpo
# Rental: NOUN   Lemma: rental
# podium: NOUN   Lemma: podium
# pocket: NOUN   Lemma: pocket
# PLplot: NOUN   Lemma: plplot
# Bronze: NOUN   Lemma: bronze
# brooms: NOUN   Lemma: broom
# demand: NOUN   Lemma: demand
# Edline: NOUN   Lemma: edline
# Delays: NOUN   Lemma: delay
# Pricer: NOUN   Lemma: pricer
# branch: NOUN   Lemma: branch
# Praise: NOUN   Lemma: praise
# Bipods: NOUN   Lemma: bipod
# edgers: NOUN   Lemma: edger
# Potash: NOUN   Lemma: potash
# refits: NOUN   Lemma: refit
# reflex: NOUN   Lemma: reflex
# Reflux: NOUN   Lemma: reflux
# Portia: NOUN   Lemma: portia
# injury: NOUN   Lemma: injury
# inlays: NOUN   Lemma: inlay
# InPage: NOUN   Lemma: inpage
# intake: NOUN   Lemma: intake
# mascot: NOUN   Lemma: mascot
# Markit: NOUN   Lemma: markit
# mantra: NOUN   Lemma: mantra
# Mantas: NOUN   Lemma: manta
# Manman: NOUN   Lemma: manman
# mammal: NOUN   Lemma: mammal
# Chucks: NOUN   Lemma: chuck
# chutes: NOUN   Lemma: chute
# Cigars: NOUN   Lemma: cigar
# Mantis: NOUN   Lemma: mantis
# import: NOUN   Lemma: import
# Humour: NOUN   Lemma: humour
# Hunter: NOUN   Lemma: hunter
# Models: NOUN   Lemma: model
# Chairs: NOUN   Lemma: chair
# mirage: NOUN   Lemma: mirage
# Mimics: NOUN   Lemma: mimic
# Metals: NOUN   Lemma: metal
# MemSQL: NOUN   Lemma: memsql
# Memory: NOUN   Lemma: memory
# charts: NOUN   Lemma: chart
# Medals: NOUN   Lemma: medal
# Comics: NOUN   Lemma: comic_strip
# Comedy: NOUN   Lemma: comedy
# Lyrics: NOUN   Lemma: lyric
# Length: NOUN   Lemma: length
# legend: NOUN   Lemma: legend
# Lauris: NOUN   Lemma: lauris
# laptop: NOUN   Lemma: laptop
# Coffee: NOUN   Lemma: coffee
# Kabyle: NOUN   Lemma: kabyle
# kayaks: NOUN   Lemma: kayak
# Kenexa: NOUN   Lemma: kenexa
# Cocoon: NOUN   Lemma: cocoon
# keypad: NOUN   Lemma: keypad
# Cobalt: NOUN   Lemma: cobalt
# Levees: NOUN   Lemma: levee
# Jasper: NOUN   Lemma: jasper
# Isatis: NOUN   Lemma: isatis
# Cirque: NOUN   Lemma: cirque
# column: NOUN   Lemma: column
# Lopper: NOUN   Lemma: lopper
# colour: NOUN   Lemma: colour
# LoJack: NOUN   Lemma: lojack
# Colors: NOUN   Lemma: color
# Cision: NOUN   Lemma: cision
# Cities: NOUN   Lemma: city
# Litmus: NOUN   Lemma: litmus
# liquid: NOUN   Lemma: liquid
# Lipper: NOUN   Lemma: lipper
# LinSig: NOUN   Lemma: linsig
# Liners: NOUN   Lemma: liner
# lights: NOUN   Lemma: light
# Combos: NOUN   Lemma: combo
# parody: NOUN   Lemma: parody
# motors: NOUN   Lemma: motor
# OpenAM: NOUN   Lemma: OpenAM
# Carbon: NOUN   Lemma: carbon
# OmegaT: NOUN   Lemma: omegat
# Credit: NOUN   Lemma: credit
# Filter: NOUN   Lemma: filter
# Cphims: NOUN   Lemma: cphim
# Flares: NOUN   Lemma: flare
# Flo-2d: NOUN   Lemma: flo-2d
# Carsim: NOUN   Lemma: carsim
# Floors: NOUN   Lemma: floor
# NYSCEF: NOUN   Lemma: nyscef
# Forbes: NOUN   Lemma: forbe
# number: NOUN   Lemma: number
# OpenNI: NOUN   Lemma: openni
# parent: NOUN   Lemma: parent
# excise: NOUN   Lemma: excise
# Exinda: NOUN   Lemma: exinda
# Family: NOUN   Lemma: family
# father: NOUN   Lemma: father
# CanLII: NOUN   Lemma: canlii
# canoes: NOUN   Lemma: canoe
# cantor: NOUN   Lemma: cantor
# Feedly: NOUN   Lemma: feedly
# female: NOUN   Lemma: female
# Coswin: NOUN   Lemma: coswin
# NetCDF: NOUN   Lemma: netcdf
# Gossip: NOUN   Lemma: gossip
# grader: NOUN   Lemma: grader
# Gravel: NOUN   Lemma: gravel
# Grease: NOUN   Lemma: grease
# Consul: NOUN   Lemma: consul
# MyTime: NOUN   Lemma: mytime
# Gloves: NOUN   Lemma: glove
# Muscle: NOUN   Lemma: muscle
# hangar: NOUN   Lemma: hangar
# Condor: NOUN   Lemma: condor
# Houses: NOUN   Lemma: house
# Murder: NOUN   Lemma: murder
# Gliffy: NOUN   Lemma: gliffy
# Glazer: NOUN   Lemma: glazer
# Fraxel: NOUN   Lemma: fraxel
# Fresco: NOUN   Lemma: fresco
# Notion: NOUN   Lemma: notion
# notary: NOUN   Lemma: notary
# Norkom: NOUN   Lemma: norkom
# friend: NOUN   Lemma: friend
# Fruits: NOUN   Lemma: fruit
# NodeXL: NOUN   Lemma: nodexl
# galaxy: NOUN   Lemma: galaxy
# Caving: NOUN   Lemma: caving
# Gamesa: NOUN   Lemma: gamesa
# gazebo: NOUN   Lemma: gazebo
# Coptis: NOUN   Lemma: coptis
# Convio: NOUN   Lemma: convio
# ghosts: NOUN   Lemma: ghost
# FinFET: NOUN   Lemma: finfet
# weaver: NOUN   Lemma: weaver
# waiver: NOUN   Lemma: waiver
# waiter: NOUN   Lemma: waiter
# Savers: NOUN   Lemma: saver
# Toxins: NOUN   Lemma: toxin
# street: NOUN   Lemma: street
# Wagons: NOUN   Lemma: wagon
# Strobe: NOUN   Lemma: strobe
# VoltDB: NOUN   Lemma: voltdb
# Alerts: NOUN   Lemma: alert
# sirens: NOUN   Lemma: siren
# Bamboo: NOUN   Lemma: bamboo
# Vissum: NOUN   Lemma: vissum
# Stunts: NOUN   Lemma: stunt
# Apttus: NOUN   Lemma: apttus
# school: NOUN   Lemma: school
# vortex: NOUN   Lemma: vortex
# tailor: NOUN   Lemma: tailor
# skiffs: NOUN   Lemma: skiff
# Tanner: NOUN   Lemma: tanner
# Steaks: NOUN   Lemma: steak
# tanker: NOUN   Lemma: tanker
# Towels: NOUN   Lemma: towel
# Tandem: NOUN   Lemma: tandem
# Towers: NOUN   Lemma: tower
# walkie: NOUN   Lemma: walkie
# WebCRM: NOUN   Lemma: WebCRM
# ArcIMS: NOUN   Lemma: arcims
# Stilts: NOUN   Lemma: stilt
# Storms: NOUN   Lemma: storm
# Stoves: NOUN   Lemma: stove
# Satire: NOUN   Lemma: satire
# WalkMe: NOUN   Lemma: WalkMe
# sauces: NOUN   Lemma: sauce
# ARCNET: NOUN   Lemma: ARCNET
# WeChat: NOUN   Lemma: wechat
# aprons: NOUN   Lemma: apron
# urchin: NOUN   Lemma: urchin
# Uptime: NOUN   Lemma: uptime
# symbol: NOUN   Lemma: symbol
# Apples: NOUN   Lemma: apple
# airbag: NOUN   Lemma: airbag
# TriNet: NOUN   Lemma: trinet
# Surfer: NOUN   Lemma: surfer
# Ultrix: NOUN   Lemma: ultrix
# Trucks: NOUN   Lemma: truck
# trusts: NOUN   Lemma: trust
# Apigee: NOUN   Lemma: apigee
# Apogee: NOUN   Lemma: apogee
# Trivia: NOUN   Lemma: trivium
# author: NOUN   Lemma: author
# Vensim: NOUN   Lemma: vensim
# vendor: NOUN   Lemma: vendor
# Anvils: NOUN   Lemma: anvil
# Apptio: NOUN   Lemma: apptio
# system: NOUN   Lemma: system
# vacuum: NOUN   Lemma: vacuum
# SysAid: NOUN   Lemma: sysaid
# Screed: NOUN   Lemma: screed
# syntax: NOUN   Lemma: syntax
# Screws: NOUN   Lemma: screw
# Vblock: NOUN   Lemma: vblock
# Silver: NOUN   Lemma: silver
# badges: NOUN   Lemma: badge
# values: NOUN   Lemma: value
# summit: NOUN   Lemma: summit
# Tugger: NOUN   Lemma: tugger
# testes: NOUN   Lemma: testis
# Slic3r: NOUN   Lemma: slic3r
# solids: NOUN   Lemma: solid
# Avatar: NOUN   Lemma: avatar
# sheers: NOUN   Lemma: sheer
# anchor: NOUN   Lemma: anchor
# Sokkia: NOUN   Lemma: sokkia
# salads: NOUN   Lemma: salad
# BartPE: NOUN   Lemma: bartpe
# Yogurt: NOUN   Lemma: yogurt
# Asthma: NOUN   Lemma: asthma
# 3Shape: NOUN   Lemma: 3shape
# shaper: NOUN   Lemma: shaper
# XForms: NOUN   Lemma: xform
# Saflok: NOUN   Lemma: saflok
# tigers: NOUN   Lemma: tiger
# Amdocs: NOUN   Lemma: amdoc
# Timers: NOUN   Lemma: timer
# Assets: NOUN   Lemma: asset
# Slides: NOUN   Lemma: slide
# toilet: NOUN   Lemma: toilet
# Wisdom: NOUN   Lemma: wisdom
# Zultys: NOUN   Lemma: zultys
# runway: NOUN   Lemma: runway
# Taulia: NOUN   Lemma: taulia
# wicket: NOUN   Lemma: wicket
# Whisky: NOUN   Lemma: whisky
# Wheels: NOUN   Lemma: wheel
# Accpac: NOUN   Lemma: Accpac
# awards: NOUN   Lemma: award
# Snacks: NOUN   Lemma: snack
# Skills: NOUN   Lemma: skill
# stator: NOUN   Lemma: stator
# Runner: NOUN   Lemma: runner
# theory: NOUN   Lemma: theory
# Aconex: NOUN   Lemma: aconex
# TDMoIP: NOUN   Lemma: tdmoip
# SQUORE: NOUN   Lemma: SQUORE
# WinQSB: NOUN   Lemma: winqsb
# Climate: NOUN   Lemma: climate
# Comfort: NOUN   Lemma: comfort
# laborer: NOUN   Lemma: laborer
# Ammonia: NOUN   Lemma: ammonia
# synchro: NOUN   Lemma: synchro
# Lacquer: NOUN   Lemma: lacquer
# Laundry: NOUN   Lemma: laundry
# closets: NOUN   Lemma: closet
# Apfloat: NOUN   Lemma: apfloat
# TeXShop: NOUN   Lemma: texshop
# Laptops: NOUN   Lemma: laptop
# Iridium: NOUN   Lemma: iridium
# columns: NOUN   Lemma: column
# Jobvite: NOUN   Lemma: Jobvite
# Tagetik: NOUN   Lemma: Tagetik
# college: NOUN   Lemma: college
# teasers: NOUN   Lemma: teaser
# javelin: NOUN   Lemma: javelin
# Kaltura: NOUN   Lemma: kaltura
# Anritsu: NOUN   Lemma: anritsu
# Talkman: NOUN   Lemma: talkman
# Tanagra: NOUN   Lemma: tanagra
# JetForm: NOUN   Lemma: jetform
# annuity: NOUN   Lemma: annuity
# Jingles: NOUN   Lemma: jingle
# Targets: NOUN   Lemma: target
# janitor: NOUN   Lemma: janitor
# Techlog: NOUN   Lemma: Techlog
# islands: NOUN   Lemma: island
# Tequila: NOUN   Lemma: tequila
# Systems: NOUN   Lemma: system
# Itanium: NOUN   Lemma: itanium
# cockpit: NOUN   Lemma: cockpit
# Anchors: NOUN   Lemma: anchor
# Keyence: NOUN   Lemma: keyence
# Tellabs: NOUN   Lemma: tellab
# Telerik: NOUN   Lemma: Telerik
# rubbers: NOUN   Lemma: rubber
# Lessons: NOUN   Lemma: lesson
# Squidoo: NOUN   Lemma: squidoo
# Artstor: NOUN   Lemma: artstor
# muffins: NOUN   Lemma: muffin
# artwork: NOUN   Lemma: artwork
# Myspace: NOUN   Lemma: myspace
# Sqlplus: NOUN   Lemma: sqlplus
# muscles: NOUN   Lemma: muscle
# Moshell: NOUN   Lemma: moshell
# Mosaics: NOUN   Lemma: mosaic
# Stencyl: NOUN   Lemma: Stencyl
# ArgoUML: NOUN   Lemma: ArgoUML
# mimicry: NOUN   Lemma: mimicry
# mindset: NOUN   Lemma: mindset
# Mirrors: NOUN   Lemma: mirror
# startup: NOUN   Lemma: startup
# monarch: NOUN   Lemma: monarch
# nacelle: NOUN   Lemma: nacelle
# Ngspice: NOUN   Lemma: ngspice
# soprano: NOUN   Lemma: soprano
# Soloist: NOUN   Lemma: soloist
# nitinol: NOUN   Lemma: nitinol
# NexTraq: NOUN   Lemma: nextraq
# Navient: NOUN   Lemma: navient
# AspectJ: NOUN   Lemma: aspectj
# sprayer: NOUN   Lemma: sprayer
# Sponges: NOUN   Lemma: sponge
# Neolane: NOUN   Lemma: neolane
# Spirent: NOUN   Lemma: spirent
# spinner: NOUN   Lemma: spinner
# Netezza: NOUN   Lemma: netezza
# Napping: NOUN   Lemma: napping
# Mergers: NOUN   Lemma: merger
# Sunrise: NOUN   Lemma: sunrise
# LoopNet: NOUN   Lemma: loopnet
# Lottery: NOUN   Lemma: lottery
# logbook: NOUN   Lemma: logbook
# Summits: NOUN   Lemma: summit
# luggage: NOUN   Lemma: luggage
# luthier: NOUN   Lemma: luthier
# Suicide: NOUN   Lemma: suicide
# Logback: NOUN   Lemma: logback
# surface: NOUN   Lemma: surface
# lexicon: NOUN   Lemma: lexicon
# Appeals: NOUN   Lemma: appeal
# AppFuse: NOUN   Lemma: appfuse
# liquids: NOUN   Lemma: liquid
# Lithium: NOUN   Lemma: lithium
# Success: NOUN   Lemma: success
# MacRuby: NOUN   Lemma: macruby
# strokes: NOUN   Lemma: stroke
# Archery: NOUN   Lemma: archery
# cheetah: NOUN   Lemma: cheetah
# Strauss: NOUN   Lemma: strauss
# Medalia: NOUN   Lemma: Medalia
# Strand7: NOUN   Lemma: Strand7
# Chatter: NOUN   Lemma: chatter
# chassis: NOUN   Lemma: chassis
# Stocker: NOUN   Lemma: stocker
# Meggers: NOUN   Lemma: megger
# student: NOUN   Lemma: student
# apricot: NOUN   Lemma: apricot
# subnets: NOUN   Lemma: subnet
# HornetQ: NOUN   Lemma: hornetq
# Engeman: NOUN   Lemma: engeman
# Enscape: NOUN   Lemma: enscape
# EntireX: NOUN   Lemma: entirex
# Washers: NOUN   Lemma: washer
# Engagio: NOUN   Lemma: Engagio
# episode: NOUN   Lemma: episode
# Wallets: NOUN   Lemma: wallet
# Epsilon: NOUN   Lemma: epsilon
# Cumulus: NOUN   Lemma: cumulus
# Culture: NOUN   Lemma: culture
# warrior: NOUN   Lemma: warrior
# Empirix: NOUN   Lemma: empirix
# Webcams: NOUN   Lemma: webcam
# edifice: NOUN   Lemma: edifice
# wedding: NOUN   Lemma: wedding
# website: NOUN   Lemma: website
# cymbals: NOUN   Lemma: cymbal
# Actemra: NOUN   Lemma: actemra
# Actifio: NOUN   Lemma: actifio
# ELISpot: NOUN   Lemma: ELISpot
# Emarsys: NOUN   Lemma: emarsy
# waivers: NOUN   Lemma: waiver
# Failure: NOUN   Lemma: failure
# Fantasy: NOUN   Lemma: fantasy
# Verseon: NOUN   Lemma: Verseon
# Crimson: NOUN   Lemma: crimson
# FastCGI: NOUN   Lemma: fastcgi
# Fatigue: NOUN   Lemma: fatigue
# veteran: NOUN   Lemma: veteran
# Vendini: NOUN   Lemma: Vendini
# vending: NOUN   Lemma: vending
# AdSense: NOUN   Lemma: adsense
# Fedwire: NOUN   Lemma: fedwire
# Cricket: NOUN   Lemma: cricket
# eyelash: NOUN   Lemma: eyelash
# vSphere: NOUN   Lemma: vSphere
# address: NOUN   Lemma: address
# CSSedit: NOUN   Lemma: cssedit
# Essbase: NOUN   Lemma: essbase
# crystal: NOUN   Lemma: crystal
# expense: NOUN   Lemma: expense
# Vintage: NOUN   Lemma: vintage
# eyebrow: NOUN   Lemma: eyebrow
# Edifecs: NOUN   Lemma: edifec
# Edi-834: NOUN   Lemma: edi-834
# Edi-820: NOUN   Lemma: edi-820
# dolphin: NOUN   Lemma: dolphin
# XStream: NOUN   Lemma: XStream
# Dracula: NOUN   Lemma: dracula
# DrayTek: NOUN   Lemma: draytek
# Dossier: NOUN   Lemma: dossier
# Divorce: NOUN   Lemma: divorce
# Zombies: NOUN   Lemma: zombie
# YouTube: NOUN   Lemma: youtube
# Dimmers: NOUN   Lemma: dimmer
# diploma: NOUN   Lemma: diploma
# DirecTV: NOUN   Lemma: DirecTV
# Yesware: NOUN   Lemma: yesware
# DataCAD: NOUN   Lemma: DataCAD
# Winplot: NOUN   Lemma: winplot
# Datatel: NOUN   Lemma: datatel
# WinBack: NOUN   Lemma: winback
# Wiegand: NOUN   Lemma: wiegand
# EasyPHP: NOUN   Lemma: easyphp
# WeVideo: NOUN   Lemma: wevideo
# Accueil: NOUN   Lemma: accueil
# AccuRev: NOUN   Lemma: accurev
# WinBUGS: NOUN   Lemma: winbugs
# Datazen: NOUN   Lemma: datazen
# witness: NOUN   Lemma: witness
# writing: NOUN   Lemma: writing
# Drucker: NOUN   Lemma: drucker
# Debussy: NOUN   Lemma: debussy
# debtors: NOUN   Lemma: debtor
# Debates: NOUN   Lemma: debate
# academy: NOUN   Lemma: academy
# Drivers: NOUN   Lemma: driver
# Ferries: NOUN   Lemma: ferry
# FFTPACK: NOUN   Lemma: fftpack
# highway: NOUN   Lemma: highway
# Alimony: NOUN   Lemma: alimony
# History: NOUN   Lemma: history
# Hobbies: NOUN   Lemma: hobby
# hexagon: NOUN   Lemma: hexagon
# Hosiery: NOUN   Lemma: hosiery
# Hospice: NOUN   Lemma: hospice
# hostler: NOUN   Lemma: hostler
# hotline: NOUN   Lemma: hotline
# Houdini: NOUN   Lemma: houdini
# Torches: NOUN   Lemma: torch
# horizon: NOUN   Lemma: horizon
# Hessian: NOUN   Lemma: hessian
# helmets: NOUN   Lemma: helmet
# Traffic: NOUN   Lemma: traffic
# Guzzler: NOUN   Lemma: guzzler
# trading: NOUN   Lemma: trading
# Alcatel: NOUN   Lemma: alcatel
# Handles: NOUN   Lemma: handle
# hazards: NOUN   Lemma: hazard
# hearses: NOUN   Lemma: hearse
# AlgoSec: NOUN   Lemma: algosec
# Housing: NOUN   Lemma: housing
# TOPdesk: NOUN   Lemma: topdesk
# Illumio: NOUN   Lemma: illumio
# company: NOUN   Lemma: company
# TimeMap: NOUN   Lemma: timemap
# Infinys: NOUN   Lemma: infiny
# Infoman: NOUN   Lemma: infoman
# threats: NOUN   Lemma: threat
# inquiry: NOUN   Lemma: inquiry
# Timpani: NOUN   Lemma: Timpani
# husband: NOUN   Lemma: husband
# Tolling: NOUN   Lemma: tolling
# toilets: NOUN   Lemma: toilet
# toggles: NOUN   Lemma: toggle
# Tkinter: NOUN   Lemma: tkinter
# Iconics: NOUN   Lemma: iconic
# Trainor: NOUN   Lemma: trainor
# grocery: NOUN   Lemma: grocery
# council: NOUN   Lemma: council
# formals: NOUN   Lemma: formal
# Foxfire: NOUN   Lemma: foxfire
# corsets: NOUN   Lemma: corset
# aerosol: NOUN   Lemma: aerosol
# FreePBX: NOUN   Lemma: freepbx
# Friends: NOUN   Lemma: friend
# frisbee: NOUN   Lemma: frisbee
# coupons: NOUN   Lemma: coupon
# Flowers: NOUN   Lemma: flower
# Figures: NOUN   Lemma: figure
# FindLaw: NOUN   Lemma: findlaw
# crayons: NOUN   Lemma: crayon
# vacuums: NOUN   Lemma: vacuum
# flagger: NOUN   Lemma: flagger
# advisor: NOUN   Lemma: advisor
# flaring: NOUN   Lemma: flaring
# Unwedge: NOUN   Lemma: unwedge
# Floater: NOUN   Lemma: floater
# Aegisub: NOUN   Lemma: Aegisub
# Tuxedos: NOUN   Lemma: tuxedo
# GROMACS: NOUN   Lemma: gromac
# tumbler: NOUN   Lemma: tumbler
# Tuition: NOUN   Lemma: tuition
# trilogy: NOUN   Lemma: trilogy
# Glitter: NOUN   Lemma: glitter
# AirDrop: NOUN   Lemma: airdrop
# Gourmet: NOUN   Lemma: gourmet
# glasses: NOUN   Lemma: glass
# trapeze: NOUN   Lemma: trapeze
# GrabCAD: NOUN   Lemma: GrabCAD
# Airsoft: NOUN   Lemma: airsoft
# graders: NOUN   Lemma: grader
# Graphic: NOUN   Lemma: graphic
# Aironet: NOUN   Lemma: aironet
# glacier: NOUN   Lemma: glacier
# Airbags: NOUN   Lemma: airbag
# Funnels: NOUN   Lemma: funnel
# tsunami: NOUN   Lemma: tsunami
# TSheets: NOUN   Lemma: tsheet
# Garbage: NOUN   Lemma: garbage
# gearbox: NOUN   Lemma: gearbox
# Gelcoat: NOUN   Lemma: gelcoat
# trocars: NOUN   Lemma: trocar
# GeoJSON: NOUN   Lemma: geojson
# FuelPHP: NOUN   Lemma: fuelphp
# Symbols: NOUN   Lemma: symbol
# Protege: NOUN   Lemma: protege
# scrotum: NOUN   Lemma: scrotum
# Renoise: NOUN   Lemma: renoise
# Biacore: NOUN   Lemma: biacore
# siphons: NOUN   Lemma: siphon
# OpenCms: NOUN   Lemma: opencms
# Sightly: NOUN   Lemma: sightly
# scorers: NOUN   Lemma: scorer
# Sandals: NOUN   Lemma: sandal
# Sandata: NOUN   Lemma: sandata
# relaxer: NOUN   Lemma: relaxer
# Bid2Win: NOUN   Lemma: bid2win
# SIDPERS: NOUN   Lemma: sidper
# bridges: NOUN   Lemma: bridge
# barmaid: NOUN   Lemma: barmaid
# Pacbase: NOUN   Lemma: pacbase
# Rentals: NOUN   Lemma: rental
# Pockets: NOUN   Lemma: pocket
# Respect: NOUN   Lemma: respect
# scalers: NOUN   Lemma: scaler
# resorts: NOUN   Lemma: resort
# Skyward: NOUN   Lemma: skyward
# baptism: NOUN   Lemma: baptism
# Bitumen: NOUN   Lemma: bitumen
# Ontario: NOUN   Lemma: ontario
# Renters: NOUN   Lemma: renter
# Plywood: NOUN   Lemma: plywood
# parents: NOUN   Lemma: parent
# Pertrac: NOUN   Lemma: pertrac
# Reptile: NOUN   Lemma: reptile
# skyline: NOUN   Lemma: skyline
# Sermons: NOUN   Lemma: sermon
# ovation: NOUN   Lemma: ovation
# Perfume: NOUN   Lemma: perfume
# puzzles: NOUN   Lemma: puzzle
# rafters: NOUN   Lemma: rafter
# Passolo: NOUN   Lemma: passolo
# Blowers: NOUN   Lemma: blower
# birding: NOUN   Lemma: birding
# Poverty: NOUN   Lemma: poverty
# Quivers: NOUN   Lemma: quiver
# Birkman: NOUN   Lemma: birkman
# shovels: NOUN   Lemma: shovel
# Captain: NOUN   Lemma: captain
# Radware: NOUN   Lemma: radware
# prisons: NOUN   Lemma: prison
# Ballads: NOUN   Lemma: ballad
# Powtoon: NOUN   Lemma: powtoon
# reasons: NOUN   Lemma: reason
# scarves: NOUN   Lemma: scarf
# Skencil: NOUN   Lemma: skencil
# RealVNC: NOUN   Lemma: RealVNC
# Autofac: NOUN   Lemma: autofac
# OpenXML: NOUN   Lemma: openxml
# Rabbits: NOUN   Lemma: rabbit
# Busways: NOUN   Lemma: busway
# Porches: NOUN   Lemma: porch
# Pegasus: NOUN   Lemma: pegasus
# Scissor: NOUN   Lemma: scissor
# Parquet: NOUN   Lemma: parquet
# QualNet: NOUN   Lemma: qualnet
# Quantel: NOUN   Lemma: quantel
# barista: NOUN   Lemma: barista
# process: NOUN   Lemma: process
# binders: NOUN   Lemma: binder
# parties: NOUN   Lemma: party
# buttons: NOUN   Lemma: button
# Brewing: NOUN   Lemma: brewing
# Simmons: NOUN   Lemma: simmon
# redback: NOUN   Lemma: redback
# Brand24: NOUN   Lemma: Brand24
# Brewery: NOUN   Lemma: brewery
# OpenMAX: NOUN   Lemma: openmax
# Problem: NOUN   Lemma: problem
# cameras: NOUN   Lemma: camera
# PostCSS: NOUN   Lemma: postcs
# posters: NOUN   Lemma: poster
# Potrace: NOUN   Lemma: potrace
# Sarcasm: NOUN   Lemma: sarcasm
# peanuts: NOUN   Lemma: peanut
# pastors: NOUN   Lemma: pastor
# PureMVC: NOUN   Lemma: puremvc
# Ploughs: NOUN   Lemma: plough
# Casamba: NOUN   Lemma: casamba
# caliber: NOUN   Lemma: caliber
# Prophix: NOUN   Lemma: prophix
# Cartels: NOUN   Lemma: cartel
# calibre: NOUN   Lemma: calibre
# prophet: NOUN   Lemma: prophet
# Paprika: NOUN   Lemma: paprika
# phpList: NOUN   Lemma: phplist
# Ormlite: NOUN   Lemma: ormlite
# Propane: NOUN   Lemma: propane
# ocarina: NOUN   Lemma: ocarina
# Bedpans: NOUN   Lemma: bedpan
# bedroom: NOUN   Lemma: bedroom
# piccolo: NOUN   Lemma: piccolo
# Pillows: NOUN   Lemma: pillow
# BlazeDS: NOUN   Lemma: blazeds
# RRDtool: NOUN   Lemma: rrdtool
# Nvision: NOUN   Lemma: nvision
# beaches: NOUN   Lemma: beach
# beacons: NOUN   Lemma: beacon
# bassoon: NOUN   Lemma: bassoon
# bassist: NOUN   Lemma: bassist
# Parades: NOUN   Lemma: parade
# Beading: NOUN   Lemma: beading
# atelier: NOUN   Lemma: atelier
# Premier: NOUN   Lemma: premier
# Papyrus: NOUN   Lemma: papyrus
# Bulimia: NOUN   Lemma: bulimia
# baskets: NOUN   Lemma: basket
# sickles: NOUN   Lemma: sickle
# Boiling: NOUN   Lemma: boiling
# avatars: NOUN   Lemma: avatar
# Benthos: NOUN   Lemma: benthos
# Sagitta: NOUN   Lemma: sagitta
# product: NOUN   Lemma: product
# Rafting: NOUN   Lemma: rafting
# Reviews: NOUN   Lemma: review
# savings: NOUN   Lemma: saving
# Retalix: NOUN   Lemma: retalix
# bobbins: NOUN   Lemma: bobbin
# puppies: NOUN   Lemma: puppy
# octopus: NOUN   Lemma: octopus
# Robbery: NOUN   Lemma: robbery
# Shaders: NOUN   Lemma: shader
# seizure: NOUN   Lemma: seizure
# buffets: NOUN   Lemma: buffet
# Phobias: NOUN   Lemma: phobia
# shearer: NOUN   Lemma: shearer
# bunions: NOUN   Lemma: bunion
# Odyssey: NOUN   Lemma: odyssey
# Panopto: NOUN   Lemma: Panopto
# ribbons: NOUN   Lemma: ribbon
# Rodents: NOUN   Lemma: rodent
# burnout: NOUN   Lemma: burnout
# Profoto: NOUN   Lemma: profoto
# Benders: NOUN   Lemma: bender
# Rockets: NOUN   Lemma: rocket
# Tributes: NOUN   Lemma: tribute
# triangle: NOUN   Lemma: triangle
# airframe: NOUN   Lemma: airframe
# glovebox: NOUN   Lemma: glovebox
# contract: NOUN   Lemma: contract
# brackets: NOUN   Lemma: bracket
# Pressure: NOUN   Lemma: pressure
# producer: NOUN   Lemma: producer
# futurist: NOUN   Lemma: futurist
# Agilysys: NOUN   Lemma: agilysys
# Seizures: NOUN   Lemma: seizure
# Funerals: NOUN   Lemma: funeral
# cornices: NOUN   Lemma: cornice
# prologue: NOUN   Lemma: prologue
# Property: NOUN   Lemma: property
# Twilight: NOUN   Lemma: twilight
# Freeware: NOUN   Lemma: freeware
# FreeRTOS: NOUN   Lemma: freerto
# Freemium: NOUN   Lemma: freemium
# Typemock: NOUN   Lemma: typemock
# Fracture: NOUN   Lemma: fracture
# fractals: NOUN   Lemma: fractal
# ProSpace: NOUN   Lemma: prospace
# Selector: NOUN   Lemma: selector
# Control4: NOUN   Lemma: control4
# Prinergy: NOUN   Lemma: prinergy
# GFortran: NOUN   Lemma: gfortran
# Genocide: NOUN   Lemma: genocide
# boutique: NOUN   Lemma: boutique
# trombone: NOUN   Lemma: trombone
# Trophies: NOUN   Lemma: trophy
# procmail: NOUN   Lemma: procmail
# Trumpets: NOUN   Lemma: trumpet
# trunking: NOUN   Lemma: trunking
# Bottling: NOUN   Lemma: bottling
# Airboats: NOUN   Lemma: airboat
# Treasure: NOUN   Lemma: treasure
# Premiere: NOUN   Lemma: premiere
# Brownies: NOUN   Lemma: brownie
# Alwayson: NOUN   Lemma: alwayson
# Platinum: NOUN   Lemma: platinum
# ideology: NOUN   Lemma: ideology
# Brooches: NOUN   Lemma: brooch
# broaches: NOUN   Lemma: broach
# Podcasts: NOUN   Lemma: podcast
# brochure: NOUN   Lemma: brochure
# HtmlUnit: NOUN   Lemma: htmlunit
# humorist: NOUN   Lemma: humorist
# hydrants: NOUN   Lemma: hydrant
# hydrates: NOUN   Lemma: hydrate
# Hydrogen: NOUN   Lemma: hydrogen
# broilers: NOUN   Lemma: broiler
# PlanGrid: NOUN   Lemma: plangrid
# inquests: NOUN   Lemma: inquest
# Insanity: NOUN   Lemma: insanity
# Intaglio: NOUN   Lemma: intaglio
# pinnacle: NOUN   Lemma: pinnacle
# Intelink: NOUN   Lemma: intelink
# Intelius: NOUN   Lemma: intelius
# interest: NOUN   Lemma: interest
# Concepts: NOUN   Lemma: concept
# informer: NOUN   Lemma: informer
# Shackles: NOUN   Lemma: shackle
# illusion: NOUN   Lemma: illusion
# Includer: NOUN   Lemma: includer
# Infantry: NOUN   Lemma: infantry
# Autotask: NOUN   Lemma: autotask
# Infoblox: NOUN   Lemma: infoblox
# Pipettes: NOUN   Lemma: pipette
# hospital: NOUN   Lemma: hospital
# consumer: NOUN   Lemma: consumer
# Braziers: NOUN   Lemma: brazier
# Traction: NOUN   Lemma: traction
# gunsmith: NOUN   Lemma: gunsmith
# Hallways: NOUN   Lemma: hallway
# Hamcrest: NOUN   Lemma: hamcrest
# Hamsters: NOUN   Lemma: hamster
# handbook: NOUN   Lemma: handbook
# Handcuff: NOUN   Lemma: handcuff
# Powertag: NOUN   Lemma: powertag
# Guardian: NOUN   Lemma: guardian
# Airports: NOUN   Lemma: airport
# airships: NOUN   Lemma: airship
# AirWatch: NOUN   Lemma: airwatch
# contacts: NOUN   Lemma: contact
# gratuity: NOUN   Lemma: gratuity
# transits: NOUN   Lemma: transit
# Brampton: NOUN   Lemma: brampton
# branches: NOUN   Lemma: branch
# Handouts: NOUN   Lemma: handout
# Handover: NOUN   Lemma: handover
# PowerCLI: NOUN   Lemma: PowerCLI
# Hightail: NOUN   Lemma: hightail
# highways: NOUN   Lemma: highway
# aligners: NOUN   Lemma: aligner
# portrait: NOUN   Lemma: portrait
# Tortoise: NOUN   Lemma: tortoise
# holidays: NOUN   Lemma: holiday
# homepage: NOUN   Lemma: homepage
# alliance: NOUN   Lemma: alliance
# polymath: NOUN   Lemma: polymath
# Concerts: NOUN   Lemma: concert
# alidades: NOUN   Lemma: alidade
# Hercules: NOUN   Lemma: hercule
# Hardinge: NOUN   Lemma: hardinge
# Alfresco: NOUN   Lemma: alfresco
# Hatchets: NOUN   Lemma: hatchet
# Headgear: NOUN   Lemma: headgear
# headwear: NOUN   Lemma: headwear
# heijunka: NOUN   Lemma: heijunka
# Blungers: NOUN   Lemma: blunger
# FORscene: NOUN   Lemma: forscene
# DataCore: NOUN   Lemma: datacore
# replicon: NOUN   Lemma: replicon
# beverage: NOUN   Lemma: beverage
# database: NOUN   Lemma: database
# Winnipeg: NOUN   Lemma: winnipeg
# WinMerge: NOUN   Lemma: winmerge
# earrings: NOUN   Lemma: earring
# EasyMock: NOUN   Lemma: easymock
# Wetsuits: NOUN   Lemma: wetsuit
# DataEase: NOUN   Lemma: dataease
# workover: NOUN   Lemma: workover
# workload: NOUN   Lemma: workload
# WorkKeys: NOUN   Lemma: workkeys
# WordStar: NOUN   Lemma: wordstar
# wordplay: NOUN   Lemma: wordplay
# Resource: NOUN   Lemma: resource
# Wireless: NOUN   Lemma: wireless
# accolade: NOUN   Lemma: accolade
# Accumulo: NOUN   Lemma: Accumulo
# EchoSign: NOUN   Lemma: echosign
# Barbecue: NOUN   Lemma: barbecue
# Einstein: NOUN   Lemma: einstein
# cylinder: NOUN   Lemma: cylinder
# election: NOUN   Lemma: election
# Ellucian: NOUN   Lemma: ellucian
# recloser: NOUN   Lemma: recloser
# Cyberoam: NOUN   Lemma: cyberoam
# workshop: NOUN   Lemma: workshop
# acronyms: NOUN   Lemma: acronym
# Accutrac: NOUN   Lemma: accutrac
# Bigtable: NOUN   Lemma: bigtable
# Eggplant: NOUN   Lemma: eggplant
# sandbags: NOUN   Lemma: sandbag
# Refugees: NOUN   Lemma: refugee
# Efficacy: NOUN   Lemma: efficacy
# sandwich: NOUN   Lemma: sandwich
# Sapphire: NOUN   Lemma: sapphire
# Websites: NOUN   Lemma: website
# dinghies: NOUN   Lemma: dinghy
# Direct2D: NOUN   Lemma: Direct2D
# displays: NOUN   Lemma: display
# Distance: NOUN   Lemma: distance
# bathroom: NOUN   Lemma: bathroom
# Roulette: NOUN   Lemma: roulette
# Diagrams: NOUN   Lemma: diagram
# Zenefits: NOUN   Lemma: zenefit
# diameter: NOUN   Lemma: diameter
# derricks: NOUN   Lemma: derrick
# receipts: NOUN   Lemma: receipt
# Xpeditor: NOUN   Lemma: xpeditor
# dragline: NOUN   Lemma: dragline
# drawings: NOUN   Lemma: drawing
# Dressage: NOUN   Lemma: dressage
# wrinkles: NOUN   Lemma: wrinkle
# retreats: NOUN   Lemma: retreat
# Worpress: NOUN   Lemma: worpress
# Drypoint: NOUN   Lemma: drypoint
# SageMath: NOUN   Lemma: sagemath
# bedrooms: NOUN   Lemma: bedroom
# deferral: NOUN   Lemma: deferral
# document: NOUN   Lemma: document
# Dogbones: NOUN   Lemma: dogbone
# Behavior: NOUN   Lemma: behavior
# Rightfax: NOUN   Lemma: rightfax
# ringtone: NOUN   Lemma: ringtone
# ringtail: NOUN   Lemma: ringtail
# Downtown: NOUN   Lemma: downtown
# Dopamine: NOUN   Lemma: dopamine
# Cuvettes: NOUN   Lemma: cuvette
# Emission: NOUN   Lemma: emission
# Emotions: NOUN   Lemma: emotion
# scooters: NOUN   Lemma: scooter
# felonies: NOUN   Lemma: felony
# festival: NOUN   Lemma: festival
# Vanities: NOUN   Lemma: vanity
# balayage: NOUN   Lemma: balayage
# pyramids: NOUN   Lemma: pyramid
# Creately: NOUN   Lemma: creately
# Valgrind: NOUN   Lemma: valgrind
# Scrubber: NOUN   Lemma: scrubber
# Firewire: NOUN   Lemma: firewire
# Feathers: NOUN   Lemma: feather
# eyeliner: NOUN   Lemma: eyeliner
# Critique: NOUN   Lemma: critique
# bluefish: NOUN   Lemma: bluefish
# families: NOUN   Lemma: family
# Fatpaint: NOUN   Lemma: fatpaint
# Qualcomm: NOUN   Lemma: qualcomm
# QuickFIX: NOUN   Lemma: quickfix
# eyebrows: NOUN   Lemma: eyebrow
# Firework: NOUN   Lemma: firework
# Fixation: NOUN   Lemma: fixation
# Flypaper: NOUN   Lemma: flypaper
# uniforms: NOUN   Lemma: uniform
# Foosball: NOUN   Lemma: foosball
# Foraging: NOUN   Lemma: foraging
# couriers: NOUN   Lemma: courier
# ProTouch: NOUN   Lemma: protouch
# cottages: NOUN   Lemma: cottage
# umbrella: NOUN   Lemma: umbrella
# costumer: NOUN   Lemma: costumer
# Bolsters: NOUN   Lemma: bolster
# backhaul: NOUN   Lemma: backhaul
# Bacteria: NOUN   Lemma: Bacteria
# Covisint: NOUN   Lemma: covisint
# Flowcode: NOUN   Lemma: flowcode
# backpack: NOUN   Lemma: backpack
# pthreads: NOUN   Lemma: pthread
# Courtois: NOUN   Lemma: courtois
# Courtesy: NOUN   Lemma: courtesy
# Coverity: NOUN   Lemma: coverity
# Proto.io: NOUN   Lemma: Proto.io
# Violence: NOUN   Lemma: violence
# Biscuits: NOUN   Lemma: biscuit
# walkways: NOUN   Lemma: walkway
# equality: NOUN   Lemma: equality
# cushions: NOUN   Lemma: cushion
# Equitrac: NOUN   Lemma: equitrac
# Culverts: NOUN   Lemma: culvert
# BankLink: NOUN   Lemma: banklink
# waitress: NOUN   Lemma: waitress
# Epilepsy: NOUN   Lemma: epilepsy
# Endeavor: NOUN   Lemma: endeavor
# Engineer: NOUN   Lemma: engineer
# RealPage: NOUN   Lemma: realpage
# Enscribe: NOUN   Lemma: enscribe
# RealFlow: NOUN   Lemma: realflow
# Vividata: NOUN   Lemma: vividata
# Exalogic: NOUN   Lemma: exalogic
# adjuvant: NOUN   Lemma: adjuvant
# Exegesis: NOUN   Lemma: exegesis
# ExifTool: NOUN   Lemma: exiftool
# scenario: NOUN   Lemma: scenario
# Blackfin: NOUN   Lemma: blackfin
# Cubicles: NOUN   Lemma: cubicle
# Vue360rx: NOUN   Lemma: vue360rx
# Rallying: NOUN   Lemma: rallying
# bandsaws: NOUN   Lemma: bandsaw
# Crushers: NOUN   Lemma: crusher
# Espresso: NOUN   Lemma: espresso
# vouchers: NOUN   Lemma: voucher
# Essayist: NOUN   Lemma: essayist
# crystals: NOUN   Lemma: crystal
# Invensys: NOUN   Lemma: invensys
# Topsides: NOUN   Lemma: topside
# Legalkey: NOUN   Lemma: legalkey
# Autobase: NOUN   Lemma: autobase
# Openfire: NOUN   Lemma: openfire
# Mixology: NOUN   Lemma: mixology
# Chancery: NOUN   Lemma: chancery
# champion: NOUN   Lemma: champion
# Autobody: NOUN   Lemma: autobody
# Sycamore: NOUN   Lemma: sycamore
# Laughter: NOUN   Lemma: laughter
# Armitage: NOUN   Lemma: armitage
# pastries: NOUN   Lemma: pastry
# chairman: NOUN   Lemma: chairman
# Lanterns: NOUN   Lemma: lantern
# Switches: NOUN   Lemma: switch
# Sweaters: NOUN   Lemma: sweater
# Swagelok: NOUN   Lemma: swagelok
# chaplain: NOUN   Lemma: chaplain
# OpenShot: NOUN   Lemma: openshot
# StatView: NOUN   Lemma: statview
# Mimecast: NOUN   Lemma: Mimecast
# OpenSees: NOUN   Lemma: opensee
# Ligation: NOUN   Lemma: ligation
# lettings: NOUN   Lemma: letting
# capybara: NOUN   Lemma: capybara
# Openness: NOUN   Lemma: openness
# minerals: NOUN   Lemma: mineral
# Signavio: NOUN   Lemma: signavio
# OpenLDAP: NOUN   Lemma: openldap
# Moldflow: NOUN   Lemma: moldflow
# Payscale: NOUN   Lemma: payscale
# Syteline: NOUN   Lemma: syteline
# Staplers: NOUN   Lemma: stapler
# Antiques: NOUN   Lemma: antique
# Knowland: NOUN   Lemma: knowland
# Staffing: NOUN   Lemma: staffing
# knockout: NOUN   Lemma: knockout
# Squirrel: NOUN   Lemma: squirrel
# audience: NOUN   Lemma: audience
# AutoForm: NOUN   Lemma: autoform
# auctions: NOUN   Lemma: auction
# cocktail: NOUN   Lemma: cocktail
# Moisture: NOUN   Lemma: moisture
# showroom: NOUN   Lemma: showroom
# Shutters: NOUN   Lemma: shutter
# OpenEdge: NOUN   Lemma: openedge
# symphony: NOUN   Lemma: symphony
# landmark: NOUN   Lemma: landmark
# landlord: NOUN   Lemma: landlord
# landfill: NOUN   Lemma: landfill
# Symposia: NOUN   Lemma: symposia
# Laborers: NOUN   Lemma: laborer
# starship: NOUN   Lemma: starship
# Synology: NOUN   Lemma: synology
# paycheck: NOUN   Lemma: paycheck
# OpenBUGS: NOUN   Lemma: openbugs
# syringes: NOUN   Lemma: syrinx
# sideboom: NOUN   Lemma: sideboom
# mustache: NOUN   Lemma: mustache
# ...
# ProClarity: NOUN   Lemma: proclarity
# Cloudworks: NOUN   Lemma: cloudwork
# Kubernetes: NOUN   Lemma: kubernete
# Processing: NOUN   Lemma: processing
# Guarantees: NOUN   Lemma: guarantee
# dimensions: NOUN   Lemma: dimension
# wheelchair: NOUN   Lemma: wheelchair
# Combatives: NOUN   Lemma: combative
# precedents: NOUN   Lemma: precedent
# Prepayment: NOUN   Lemma: prepayment
# Guidelines: NOUN   Lemma: guideline
# goniometer: NOUN   Lemma: goniometer
# ironworker: NOUN   Lemma: ironworker
# Wikispaces: NOUN   Lemma: wikispace
# Wilderness: NOUN   Lemma: wilderness
# Chromecast: NOUN   Lemma: chromecast
# Biomarkers: NOUN   Lemma: biomarker
# Datastream: NOUN   Lemma: datastream
# pedestrian: NOUN   Lemma: pedestrian
# TradeGecko: NOUN   Lemma: tradegecko
# Ratemaking: NOUN   Lemma: ratemaking
# Fumigation: NOUN   Lemma: fumigation
# debentures: NOUN   Lemma: debenture
# trampoline: NOUN   Lemma: trampoline
# earthquake: NOUN   Lemma: earthquake
# Alcoholism: NOUN   Lemma: alcoholism
# hardscapes: NOUN   Lemma: hardscape
# trackballs: NOUN   Lemma: trackball
# pedometers: NOUN   Lemma: pedometer
# BlazeMeter: NOUN   Lemma: blazemeter
# recitation: NOUN   Lemma: recitation
# Locksmiths: NOUN   Lemma: locksmith
# Headphones: NOUN   Lemma: headphone
# integrator: NOUN   Lemma: integrator
# Aggression: NOUN   Lemma: aggression
# tumbleweed: NOUN   Lemma: tumbleweed
# passengers: NOUN   Lemma: passenger
# turnstiles: NOUN   Lemma: turnstile
# blacklight: NOUN   Lemma: blacklight
# Connectrix: NOUN   Lemma: connectrix
# Macroscope: NOUN   Lemma: macroscope
# triathlete: NOUN   Lemma: triathlete
# pawnbroker: NOUN   Lemma: pawnbroker
# insurgency: NOUN   Lemma: insurgency
# bloodhound: NOUN   Lemma: bloodhound
# Uniqueness: NOUN   Lemma: uniqueness
# Corkscrews: NOUN   Lemma: corkscrew
# Committees: NOUN   Lemma: committee
# Quotations: NOUN   Lemma: quotation
# dashboards: NOUN   Lemma: dashboard
# Upholstery: NOUN   Lemma: upholstery
# Clarifiers: NOUN   Lemma: clarifier
# MailEnable: NOUN   Lemma: mailenable
# allegiance: NOUN   Lemma: allegiance
# Binoculars: NOUN   Lemma: binocular
# university: NOUN   Lemma: university
# gatekeeper: NOUN   Lemma: gatekeeper
# Travertine: NOUN   Lemma: travertine
# ediscovery: NOUN   Lemma: ediscovery
# Reductions: NOUN   Lemma: reduction
# BitTorrent: NOUN   Lemma: bittorrent
# Airfreight: NOUN   Lemma: airfreight
# Harassment: NOUN   Lemma: harassment
# Literature: NOUN   Lemma: literature
# QuickPlace: NOUN   Lemma: quickplace
# TortoiseHg: NOUN   Lemma: tortoisehg
# Fungicides: NOUN   Lemma: fungicide
# Ungerboeck: NOUN   Lemma: ungerboeck
# PEGylation: NOUN   Lemma: pegylation
# Crashlytics: NOUN   Lemma: crashlytic
# resistivity: NOUN   Lemma: resistivity
# cornerstone: NOUN   Lemma: cornerstone
# Parachuting: NOUN   Lemma: parachuting
# concussions: NOUN   Lemma: concussion
# requirement: NOUN   Lemma: requirement
# Fundraising: NOUN   Lemma: fundraising
# corrections: NOUN   Lemma: correction
# Goconcierge: NOUN   Lemma: goconcierge
# Goalkeeping: NOUN   Lemma: goalkeeping
# Furnishings: NOUN   Lemma: furnishing
# BigMachines: NOUN   Lemma: bigmachine
# Omnichannel: NOUN   Lemma: omnichannel
# Carrosserie: NOUN   Lemma: carrosserie
# Observation: NOUN   Lemma: observation
# partnership: NOUN   Lemma: partnership
# Containment: NOUN   Lemma: containment
# Granulation: NOUN   Lemma: granulation
# Bridesmaids: NOUN   Lemma: bridesmaid
# Caricatures: NOUN   Lemma: caricature
# credentials: NOUN   Lemma: credential
# remittances: NOUN   Lemma: remittance
# Renaissance: NOUN   Lemma: renaissance
# Homebrewing: NOUN   Lemma: homebrewing
# Credibility: NOUN   Lemma: credibility
# respiratory: NOUN   Lemma: respiratory
# Contentment: NOUN   Lemma: contentment
# playgrounds: NOUN   Lemma: playground
# calculators: NOUN   Lemma: calculator
# PacketCable: NOUN   Lemma: packetcable
# scholarship: NOUN   Lemma: scholarship
# handicrafts: NOUN   Lemma: handicraft
# Originality: NOUN   Lemma: originality
# origination: NOUN   Lemma: origination
# Punctuality: NOUN   Lemma: punctuality
# Punctuation: NOUN   Lemma: punctuation
# Oscillation: NOUN   Lemma: oscillation
# performance: NOUN   Lemma: performance
# perforation: NOUN   Lemma: perforation
# roundabouts: NOUN   Lemma: roundabout
# Butterknife: NOUN   Lemma: butterknife
# Pedodontics: NOUN   Lemma: pedodontic
# Perishables: NOUN   Lemma: perishable
# Perforating: NOUN   Lemma: perforating
# Forbearance: NOUN   Lemma: forbearance
# handwashing: NOUN   Lemma: handwashing
# Buttercream: NOUN   Lemma: buttercream
# Foreclosure: NOUN   Lemma: foreclosure
# Forgiveness: NOUN   Lemma: forgiveness
# overcurrent: NOUN   Lemma: overcurrent
# hierarchies: NOUN   Lemma: hierarchy
# overvoltage: NOUN   Lemma: overvoltage
# Consignment: NOUN   Lemma: consignment
# Peacemaking: NOUN   Lemma: peacemaking
# PhotoImpact: NOUN   Lemma: photoimpact
# Retaliation: NOUN   Lemma: retaliation
# Gunsmithing: NOUN   Lemma: gunsmithing
# Salamanders: NOUN   Lemma: salamander
# ProcessWire: NOUN   Lemma: processwire
# correlation: NOUN   Lemma: correlation
# Franchising: NOUN   Lemma: franchising
# Bookmobiles: NOUN   Lemma: bookmobile
# ghostwriter: NOUN   Lemma: ghostwriter
# Convenience: NOUN   Lemma: convenience
# CoverMyMeds: NOUN   Lemma: covermymed
# ProRealTime: NOUN   Lemma: prorealtime
# Bereavement: NOUN   Lemma: bereavement
# flashlights: NOUN   Lemma: flashlight
# Bookbinding: NOUN   Lemma: bookbinding
# Fleetmatics: NOUN   Lemma: fleetmatic
# prospection: NOUN   Lemma: prospection
# Obfuscation: NOUN   Lemma: obfuscation
# commercials: NOUN   Lemma: commercial
# Tripadvisor: NOUN   Lemma: tripadvisor
# Citizenship: NOUN   Lemma: citizenship
# Made2Manage: NOUN   Lemma: made2manage
# EclipseLink: NOUN   Lemma: eclipselink
# eavestrough: NOUN   Lemma: eavestrough
# Daylighting: NOUN   Lemma: daylighting
# unigraphics: NOUN   Lemma: unigraphic
# decompilers: NOUN   Lemma: decompiler
# Agoraphobia: NOUN   Lemma: agoraphobia
# Turnarounds: NOUN   Lemma: turnaround
# ellipticals: NOUN   Lemma: elliptical
# inflatables: NOUN   Lemma: inflatable
# influencers: NOUN   Lemma: influencer
# Measurement: NOUN   Lemma: measurement
# Temperature: NOUN   Lemma: temperature
# Information: NOUN   Lemma: information
# Terminology: NOUN   Lemma: terminology
# Cybersource: NOUN   Lemma: cybersource
# syndication: NOUN   Lemma: syndication
# methodology: NOUN   Lemma: methodology
# synthesizer: NOUN   Lemma: synthesizer
# Antibribery: NOUN   Lemma: antibribery
# Indigestion: NOUN   Lemma: indigestion
# chocolatier: NOUN   Lemma: chocolatier
# alternators: NOUN   Lemma: alternator
# commodities: NOUN   Lemma: commodity
# maintenance: NOUN   Lemma: maintenance
# tournaments: NOUN   Lemma: tournament
# tourniquets: NOUN   Lemma: tourniquet
# Matchmaking: NOUN   Lemma: matchmaking
# effectivity: NOUN   Lemma: effectivity
# Amontillado: NOUN   Lemma: amontillado
# thesauruses: NOUN   Lemma: thesaurus
# ingredients: NOUN   Lemma: ingredient
# ThoughtSpot: NOUN   Lemma: thoughtspot
# marketplace: NOUN   Lemma: marketplace
# Communities: NOUN   Lemma: community
# indentation: NOUN   Lemma: indentation
# Ironworkers: NOUN   Lemma: ironworker
# Cockroaches: NOUN   Lemma: cockroach
# windcatcher: NOUN   Lemma: windcatcher
# Whiteboards: NOUN   Lemma: whiteboard
# Kirkpatrick: NOUN   Lemma: kirkpatrick
# withholding: NOUN   Lemma: withholding
# accompanist: NOUN   Lemma: accompanist
# Wheelchairs: NOUN   Lemma: wheelchair
# Istopmotion: NOUN   Lemma: istopmotion
# 3DEqualizer: NOUN   Lemma: 3dequalizer
# Yachtmaster: NOUN   Lemma: yachtmaster
# Codeignitor: NOUN   Lemma: codeignitor
# Absenteeism: NOUN   Lemma: absenteeism
# Abstraction: NOUN   Lemma: abstraction
# collocation: NOUN   Lemma: collocation
# Diagnostics: NOUN   Lemma: diagnostic
# WorldTracer: NOUN   Lemma: worldtracer
# Disarmament: NOUN   Lemma: disarmament
# Definitions: NOUN   Lemma: definition
# Victimology: NOUN   Lemma: victimology
# Letterpress: NOUN   Lemma: letterpress
# Internships: NOUN   Lemma: internship
# Deductibles: NOUN   Lemma: deductible
# disposables: NOUN   Lemma: disposable
# watercolour: NOUN   Lemma: watercolour
# Lampworking: NOUN   Lemma: lampworking
# Lamborghini: NOUN   Lemma: Lamborghini
# Actionnaire: NOUN   Lemma: actionnaire
# Microcredit: NOUN   Lemma: microcredit
# Escheatment: NOUN   Lemma: escheatment
# Caterpillar: NOUN   Lemma: caterpillar
# spokeshaves: NOUN   Lemma: spokeshave
# Iconography: NOUN   Lemma: iconography
# Moxibustion: NOUN   Lemma: moxibustion
# MSC.Nastran: NOUN   Lemma: msc.nastran
# speculation: NOUN   Lemma: speculation
# facilitator: NOUN   Lemma: facilitator
# Evaporation: NOUN   Lemma: evaporation
# Competition: NOUN   Lemma: competition
# Stewardship: NOUN   Lemma: stewardship
# Stevedoring: NOUN   Lemma: stevedoring
# steamfitter: NOUN   Lemma: steamfitter
# autoencoder: NOUN   Lemma: autoencoder
# arrangement: NOUN   Lemma: arrangement
# exhortation: NOUN   Lemma: exhortation
# exoskeleton: NOUN   Lemma: exoskeleton
# extradition: NOUN   Lemma: extradition
# expungement: NOUN   Lemma: expungement
# SlideShare: NOUN   Lemma: slideshare
# Exploration: NOUN   Lemma: exploration
# Experiments: NOUN   Lemma: experiment
# exhibitions: NOUN   Lemma: exhibition
# CrowdStrike: NOUN   Lemma: crowdstrike
# Grasshopper: NOUN   Lemma: grasshopper
# multiplayer: NOUN   Lemma: multiplayer
# SimulationX: NOUN   Lemma: simulationx
# SinglePoint: NOUN   Lemma: singlepoint
# Compositing: NOUN   Lemma: compositing
# Netnography: NOUN   Lemma: netnography
# Auxiliaries: NOUN   Lemma: auxiliary
# Chandeliers: NOUN   Lemma: chandelier
# entertainer: NOUN   Lemma: entertainer
# supermarket: NOUN   Lemma: supermarket
# Substations: NOUN   Lemma: substation
# Improvement: NOUN   Lemma: improvement
# Mindfulness: NOUN   Lemma: mindfulness
# Subrogation: NOUN   Lemma: subrogation
# suppository: NOUN   Lemma: suppository
# stopwatches: NOUN   Lemma: stopwatch
# Sweepstakes: NOUN   Lemma: sweepstake
# stockpiling: NOUN   Lemma: stockpiling
# Apologetics: NOUN   Lemma: apologetic
# entitlement: NOUN   Lemma: entitlement
# enumeration: NOUN   Lemma: enumeration
# Observations: NOUN   Lemma: observation
# Jurisdiction: NOUN   Lemma: jurisdiction
# Cohabitation: NOUN   Lemma: cohabitation
# Nomenclature: NOUN   Lemma: nomenclature
# Code::Blocks: NOUN   Lemma: code::block
# Homesteading: NOUN   Lemma: homesteading
# Kindergarten: NOUN   Lemma: kindergarten
# kaleidoscope: NOUN   Lemma: kaleidoscope
# Guardianship: NOUN   Lemma: guardianship
# PhotoModeler: NOUN   Lemma: photomodeler
# Invigilation: NOUN   Lemma: invigilation
# CloudCompare: NOUN   Lemma: cloudcompare
# microfilmers: NOUN   Lemma: microfilmer
# Mobilisation: NOUN   Lemma: mobilisation
# Malnutrition: NOUN   Lemma: malnutrition
# marketplaces: NOUN   Lemma: marketplace
# Marksmanship: NOUN   Lemma: marksmanship
# Mobilization: NOUN   Lemma: mobilization
# modeFRONTIER: NOUN   Lemma: modeFRONTIER
# Institutions: NOUN   Lemma: institution
# organisation: NOUN   Lemma: organisation
# organization: NOUN   Lemma: organization
# Chairmanship: NOUN   Lemma: chairmanship
# Microfinance: NOUN   Lemma: microfinance
# Configurator: NOUN   Lemma: configurator
# megohmmeters: NOUN   Lemma: megohmmeter
# CircuitMaker: NOUN   Lemma: circuitmaker
# confirmation: NOUN   Lemma: confirmation
# measurements: NOUN   Lemma: measurement
# cheerleading: NOUN   Lemma: cheerleading
# Commutations: NOUN   Lemma: commutation
# Hypnotherapy: NOUN   Lemma: hypnotherapy
# Clickability: NOUN   Lemma: clickability
# neighborhood: NOUN   Lemma: neighborhood
# Locksmithing: NOUN   Lemma: locksmithing
# optimization: NOUN   Lemma: optimization
# liquefaction: NOUN   Lemma: liquefaction
# Clairvoyance: NOUN   Lemma: clairvoyance
# conditioning: NOUN   Lemma: conditioning
# municipality: NOUN   Lemma: municipality
# Intercession: NOUN   Lemma: intercession
# Peacekeeping: NOUN   Lemma: peacekeeping
# Intelligence: NOUN   Lemma: intelligence
# condominiums: NOUN   Lemma: condominium
# Harpsichords: NOUN   Lemma: harpsichord
# Universities: NOUN   Lemma: university
# availability: NOUN   Lemma: availability
# Shareholders: NOUN   Lemma: shareholder
# Urbanization: NOUN   Lemma: urbanization
# ExtendScript: NOUN   Lemma: extendscript
# extroversion: NOUN   Lemma: extroversion
# Shuffleboard: NOUN   Lemma: shuffleboard
# Silverstripe: NOUN   Lemma: silverstripe
# S.T.A.B.L.E.: NOUN   Lemma: s.t.a.b.l.e.
# segmentation: NOUN   Lemma: segmentation
# scholarships: NOUN   Lemma: scholarship
# schoolmaster: NOUN   Lemma: schoolmaster
# Scrapbooking: NOUN   Lemma: scrapbooking
# screenwriter: NOUN   Lemma: screenwriter
# valorisation: NOUN   Lemma: valorisation
# Testimonials: NOUN   Lemma: testimonial
# subscription: NOUN   Lemma: subscription
# Electricians: NOUN   Lemma: electrician
# subsidiaries: NOUN   Lemma: subsidiary
# supermarkets: NOUN   Lemma: supermarket
# stroboscopes: NOUN   Lemma: stroboscope
# Supportworks: NOUN   Lemma: supportwork
# entitlements: NOUN   Lemma: entitlement
# straitjacket: NOUN   Lemma: straitjacket
# Ticketmaster: NOUN   Lemma: ticketmaster
# encyclopedia: NOUN   Lemma: encyclopedia
# Embezzlement: NOUN   Lemma: embezzlement
# Synthesizers: NOUN   Lemma: synthesizer
# Syndications: NOUN   Lemma: syndication
# Survivorship: NOUN   Lemma: survivorship
# Swordmanship: NOUN   Lemma: swordmanship
# Transmittals: NOUN   Lemma: transmittal
# transceivers: NOUN   Lemma: transceiver
# Trampolining: NOUN   Lemma: trampolining
# Transmitters: NOUN   Lemma: transmitter
# Transporters: NOUN   Lemma: transporter
# expenditures: NOUN   Lemma: expenditure
# Expatriation: NOUN   Lemma: expatriation
# cultipackers: NOUN   Lemma: cultipacker
# eFileCabinet: NOUN   Lemma: efilecabinet
# Trabajadores: NOUN   Lemma: trabajadore
# spokesperson: NOUN   Lemma: spokesperson
# countersinks: NOUN   Lemma: countersink
# wheelbarrows: NOUN   Lemma: wheelbarrow
# reconnection: NOUN   Lemma: reconnection
# RecoverPoint: NOUN   Lemma: recoverpoint
# Disabilities: NOUN   Lemma: disability
# Redeployment: NOUN   Lemma: redeployment
# Birdwatching: NOUN   Lemma: birdwatching
# Receptionist: NOUN   Lemma: receptionist
# dictionaries: NOUN   Lemma: dictionary
# Depreciation: NOUN   Lemma: depreciation
# Workshopping: NOUN   Lemma: workshopping
# Productivity: NOUN   Lemma: productivity
# pyranometers: NOUN   Lemma: pyranometer
# conveyancing: NOUN   Lemma: conveyancing
# acceleration: NOUN   Lemma: acceleration
# disbursement: NOUN   Lemma: disbursement
# dispositions: NOUN   Lemma: disposition
# warehouseman: NOUN   Lemma: warehouseman
# Fontographer: NOUN   Lemma: fontographer
# counterpoint: NOUN   Lemma: counterpoint
# Followership: NOUN   Lemma: followership
# counterbores: NOUN   Lemma: counterbore
# Repatriation: NOUN   Lemma: repatriation
# Rejuvenation: NOUN   Lemma: rejuvenation
# Requirements: NOUN   Lemma: requirement
# Repossession: NOUN   Lemma: repossession
# Discipleship: NOUN   Lemma: discipleship
# Restatements: NOUN   Lemma: restatement
# Retrenchment: NOUN   Lemma: retrenchment
# accelerometer: NOUN   Lemma: accelerometer
# Childrenswear: NOUN   Lemma: childrenswear
# Thermocouples: NOUN   Lemma: thermocouple
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <cell line: 7>()
#       6 lemmas = []
#       7 for skill in all_df.skill_title.tolist():
# ----> 8     doc = nlp(skill)
#       9     if len(doc)== 1:                               #Find unigram
#      10         for token in doc:
#
# File ~\anaconda3\lib\site-packages\spacy\language.py:1008, in Language.__call__(self, text, disable, component_cfg)
#     987 def __call__(
#     988     self,
#     989     text: Union[str, Doc],
#    (...)
#     992     component_cfg: Optional[Dict[str, Dict[str, Any]]] = None,
#     993 ) -> Doc:
#     994     """Apply the pipeline to some text. The text can span multiple sentences,
#     995     and can contain arbitrary whitespace. Alignment into the original string
#     996     is preserved.
#    (...)
#    1006     DOCS: https://spacy.io/api/language#call
#    1007     """
# -> 1008     doc = self._ensure_doc(text)
#    1009     if component_cfg is None:
#    1010         component_cfg = {}
#
# File ~\anaconda3\lib\site-packages\spacy\language.py:1102, in Language._ensure_doc(self, doc_like)
#    1100 if isinstance(doc_like, bytes):
#    1101     return Doc(self.vocab).from_bytes(doc_like)
# -> 1102 raise ValueError(Errors.E1041.format(type=type(doc_like)))
#
# ValueError: [E1041] Expected a string, Doc, or bytes as input, but got: <class 'float'>

# %%
len(lemmas)
# Out:
# 22510

# %%
df = pd.DataFrame({'noun_unigram_lemmas':lemmas})
df.to_excel("noun_unigram_lemmas.xlsx")

# %%
df.to_parquet("noun_unigram_lemmas.parquet")

# %%
pip install --upgrade pip

# %%
pip install Polyglot

# %%
all_df['noun_unigram_lemma'] = lemmas
all_df.to_excel('merged_file_lemmas_added.xlsx')

# %%
parquet_df = pd.read_excel('merged_file.xlsx')

# %%
parquet_df.to_parquet('merged_file.parquet')
