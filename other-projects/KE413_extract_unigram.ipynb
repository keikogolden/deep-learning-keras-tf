# %%
import spacy
import pandas as pd

# %%
df = pd.read_excel("C:/Users/KeikoGolden/ComputationalLiguistics/KE413/proedge_delivery.xlsx")
df
# Out:
#        Unnamed: 0.1  Unnamed: 0             skill_title  \
# 0                 0         0.0                     SF6
# 1                 1         1.0                    Redd
# 2                 2         2.0                    RFID
# 3                 3         3.0                    FTIR
# 4                 4         4.0                  review
# ...             ...         ...                     ...
# 24949          1820      3646.0  Weight Loss Counseling
# 24950          1821      3647.0   WH Software MasterKey
# 24951          1822      3648.0  Wire Twisting Scissors
# 24952          1823      3649.0             Wire Whisks
# 24953          1824      3650.0            Wire Winches
#
#                                 Suggested_skill_title skill_or_not  \
# 0                                                 NaN           no
# 1                                               Redd+           no
# 2                                               RFID+          yes
# ...

# %%
# Extract unigramsfro the input file
nlp = spacy.load("en_core_web_lg")

unigrams = []
for skill in df.skill_title:
    doc = nlp(skill)
    if len(doc)== 1:                               
        unigrams.append(doc)

# %%
len(unigrams)
# Out:
# 3937

# %%
result_df = pd.DataFrame({'unigrams': unigrams})
result_df.to_excel('unigrams.xlsx')

# %%
unigram_df = pd.read_excel("C:/Users/KeikoGolden/ComputationalLiguistics/KE413/proedge_delivery_unigram.xlsx")
unigram_df
# Out:
#       Unnamed: 0.1  Unnamed: 0    skill_title  \
# 0                0         0.0            SF6
# 1                1         1.0           Redd
# 2                2         2.0           RFID
# 3                3         3.0           FTIR
# 4                4         4.0         review
# ...            ...         ...            ...
# 3931          1398      3224.0       Torvanes
# 3932          1431      3257.0       trackhoe
# 3933          1717      3543.0    Unityscript
# 3934          1726      3552.0  Uroflowmeters
# 3935          1802      3628.0     Volumeters
#
#                                Suggested_skill_title skill_or_not in_ontology  \
# 0                                                NaN           no          no
# 1                                              Redd+           no          no
# 2                                              RFID+          yes          no
# 3     Fourier-Transform Infrared Spectroscopy (FTIR)          yes          no
# ...

# %%
3936/5
# Out:
# 787.2

# %%
df1 = unigram_df[0:787]
df2 = unigram_df[787:1574]
df3 = unigram_df[1574:2361]
df4 = unigram_df[2361:3148]
df5 = unigram_df[3148:-1]

# %%
df1.to_excel("unigram_anay.xlsx")
df2.to_excel("unigram_cassady.xlsx")
df3.to_excel("unigram_desiree.xlsx")
df4.to_excel("unigram_ethan.xlsx")
df5.to_excel("unigram_syed.xlsx")

# %%
# Extract rows with the unigram

unigram_rows = []
for _, row in df.iterrows():
    if row['skill_title'] in unigrams:
        unigram_rows.append(row)
        unigram_rows.append(df[0])

# %%
# Extract rows with the unigram

result_df = pd.DataFrame()
for index, row in df.iterrows():
    if row['skill_title'] in unigrams:
        result_df = pd.concat([result_df, df[index]])

# %%
result_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Create annotation spreadsheet.
result_df = DataFrame({'unigram':unigram_rows})
